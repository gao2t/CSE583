# %%
import pandas as pd
import numpy as np
import datetime

# %%
#Read the CSV file into a pandas dataframe
df = pd.read_csv("/Users/tianyue/project/data/bicycle_data.csv")
print(data)
# Out:
#                      Unnamed: 0  Fremont Bridge Total  \
# Date
# 2016-01-01 00:00:00       29184                  18.0
# 2016-01-01 01:00:00       29185                  15.0
# 2016-01-01 02:00:00       29186                  11.0
# 2016-01-01 03:00:00       29187                   7.0
# 2016-01-01 04:00:00       29188                   2.0
# ...                         ...                   ...
# 2016-12-31 19:00:00       37963                  10.0
# 2016-12-31 20:00:00       37964                   9.0
# 2016-12-31 21:00:00       37965                  10.0
# 2016-12-31 22:00:00       37966                  15.0
# 2016-12-31 23:00:00       37967                   8.0
#
#                      Fremont Bridge East Sidewalk  \
# Date
# 2016-01-01 00:00:00                           9.0
# 2016-01-01 01:00:00                           3.0
# 2016-01-01 02:00:00                           6.0
# 2016-01-01 03:00:00                           1.0
# ...

# %%
#The total (East + West) bicycle count 
df['The total (East + West) bicycle count'] = df['Fremont Bridge East Sidewalk'] + df['Fremont Bridge West Sidewalk']
#The hour of the day
df['date'] = pd.to_datetime(df['Date'])
df['Hour of the day'] = df['date'].dt.hour
#The year
df['The year'] = df['date'].dt.year
df.head()
# Out:
#                      Date  Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# 0  08/01/2022 12:00:00 AM                  23.0                           7.0
# 1  08/01/2022 01:00:00 AM                  12.0                           5.0
# 2  08/01/2022 02:00:00 AM                   3.0                           0.0
# 3  08/01/2022 03:00:00 AM                   5.0                           2.0
# 4  08/01/2022 04:00:00 AM                  10.0                           2.0
#
#    Fremont Bridge West Sidewalk  The total (East + West) bicycle count  \
# 0                          16.0                                   23.0
# 1                           7.0                                   12.0
# 2                           3.0                                    3.0
# 3                           3.0                                    5.0
# 4                           8.0                                   10.0
#
#                  date  Hour of the day  The year
# ...

# %%
#Create a new dataframe with the subset of data from the year 2016
df2016 = df[df['The year'] == 2016]
df2016
# Out:
#                          Date  Fremont Bridge Total  \
# 29184  01/01/2016 12:00:00 AM                  18.0
# 29185  01/01/2016 01:00:00 AM                  15.0
# 29186  01/01/2016 02:00:00 AM                  11.0
# 29187  01/01/2016 03:00:00 AM                   7.0
# 29188  01/01/2016 04:00:00 AM                   2.0
# ...                       ...                   ...
# 37963  12/31/2016 07:00:00 PM                  10.0
# 37964  12/31/2016 08:00:00 PM                   9.0
# 37965  12/31/2016 09:00:00 PM                  10.0
# 37966  12/31/2016 10:00:00 PM                  15.0
# 37967  12/31/2016 11:00:00 PM                   8.0
#
#        Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk  \
# 29184                           9.0                           9.0
# 29185                           3.0                          12.0
# 29186                           6.0                           5.0
# 29187                           1.0                           6.0
# ...

# %%
#plot the counts by hour
import matplotlib.pyplot as plt
import matplotlib as mpl
data2016 = df2016.drop(columns = ['The total (East + West) bicycle count','date','The year'])
data2016
# Out:
#                          Date  Fremont Bridge Total  \
# 29184  01/01/2016 12:00:00 AM                  18.0
# 29185  01/01/2016 01:00:00 AM                  15.0
# 29186  01/01/2016 02:00:00 AM                  11.0
# 29187  01/01/2016 03:00:00 AM                   7.0
# 29188  01/01/2016 04:00:00 AM                   2.0
# ...                       ...                   ...
# 37963  12/31/2016 07:00:00 PM                  10.0
# 37964  12/31/2016 08:00:00 PM                   9.0
# 37965  12/31/2016 09:00:00 PM                  10.0
# 37966  12/31/2016 10:00:00 PM                  15.0
# 37967  12/31/2016 11:00:00 PM                   8.0
#
#        Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk  \
# 29184                           9.0                           9.0
# 29185                           3.0                          12.0
# 29186                           6.0                           5.0
# 29187                           1.0                           6.0
# ...

# %%
by_time = data2016.groupby('Hour of the day').sum()
by_time = by_time.reset_index()
by_time
# Out:
#     Hour of the day  Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# 0                 0                3910.0                        1708.0
# 1                 1                2025.0                         907.0
# 2                 2                1265.0                         527.0
# 3                 3                 781.0                         383.0
# 4                 4                2240.0                        1222.0
# 5                 5               10154.0                        6430.0
# 6                 6               34882.0                       22317.0
# 7                 7               89624.0                       60685.0
# 8                 8              121438.0                       77959.0
# 9                 9               68366.0                       39863.0
# 10               10               34856.0                       19109.0
# 11               11               29759.0                       15857.0
# ...

# %%
plt.plot(by_time['Hour of the day'], by_time['Fremont Bridge Total'])

# %%
#determine what is (on average) the busiest hour of the day 
maxvaluetime = by_time['Fremont Bridge Total'].idxmax()
print('The busiest hour of the day is the hour', maxvaluetime)
# Out:
# The busiest hour of the day is the hour 17
